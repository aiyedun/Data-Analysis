# %% [markdown]
# # TABULATION OF DATA
#
#
# ![Data%20Science%20Beginner%20Training%20%284%29.png](attachment:Data%20Science%20Beginner%20Training%20%284%29.png)

# %% [markdown]
# what is structured Data?
# - organized in a tabular format with rows and columns.
# - There is a relationship between the rows and columns.
# - Data in a row contains information that describes a single entity, while data in a column describes a field of information all entities possess.
#
# - Excel sheet, CSV files

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Tabulation of Data
#
# Tabulation of data is an essential skill for anyone working with information, regardless of the field or profession. It is a method of structuring data in tabular form, using rows and columns, to facilitate better comprehension, analysis, and decision-making.
# we will explore the key **concepts**, **benefits**, and **best practices** of tabularizing data to equip you with the knowledge and tools needed to effectively handle and utilize information.
#
#
#
# ### Benefits of Tabulating a data
# - Streamlined data comparison and analysis.
# - Improved data visualization for easier interpretation.
# - Enhanced data aggregation and summarization.
# - Efficient data entry and validation.
# - Scalability and adaptability in handling large datasets

# %% [markdown]
# #### Quick Detour!
#
# Dictionaries a data type that stores data in key-value pairs. They are changeable, you can add, remove, items from a dictionary
#
# Syntax
# mydic = {'key': 'value'}

# %%
# creating a dictionary
mydic = {'name': 'Joana',
'surname': ['Owusu-Appiah','Appiah']
}
print(mydic)

# %%
# number of items
len(mydic)

# %%
mydic.get('surname')

# %%
# prints the keys
mydic.keys()

# %%
# prints the values
mydic.values()

# %%
# adds a new item to the dictionary

mydic["color"] = "red"
mydic

# %%
# removes items from the dictionary

mydic.pop('color')
mydic

# %% [markdown]
# #### Working with Lists

# %%
A = ['a', 'b', 'c', 'd']
A

# %%
A[1]

# %%
A[-1]

# %% [markdown]
# ### TABULATING DATA IN PANDAS
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# Pandas can be used to clean, explore, and manipulate data.
# The major datatypes in Pandas are Series and DataFrames
#
# - Series : think of a column  in an excel sheet. Series is a 1D array capable of holding any data type. Series has vertical labels called Indexes.
# - DataFrame : contains a number of Series. 2D data structure with rows and columns. Picture a table with rows and columns within an Excel file

# %%
# !pip install pandas

# %%
# import the libraries
import pandas as pd

# import pandas

# %%
# creates a Series
print(pd.Series([1, 2, 3]))

# %%
# specifies the index
print(pd.Series([1, 2, 3], index=['a', 'b', 'c'])) # with index

# %%
# converting a dictionary into a pandas dataframe
mycars = {
  'cars': ["Range rover", "BMW", "Ford Raptor"],
    'colors':['green', 'blue', 'purple'],
  'years': [2028, 2030, 2035]
}

cars = pd.DataFrame(mycars)

print(cars)

# %%
cars.tail()

# %%
# reading a csv file
presidents_df = pd.read_csv('https://sololearn.com/uploads/files/president_heights_party.csv', index_col='name')

# returns the first 5 rows
presidents_df.head()

# %%
# returns the number of rows and columns
presidents_df.shape

# %%
# returns the number of elements
# rows * columns

presidents_df.size

# %%
# returns last 5 rows
presidents_df.tail(10)

# %%
# summary statistics of the data 
presidents_df.describe()

# %%
# check the number of missing values
# the data types of the columns
presidents_df.info()

# %%
# looks for the row with the specified name
# prints the entire row

presidents_df.loc['George W. Bush']

# %%
# categorical variables in our dataset
# counts the unique values
presidents_df['party'].value_counts()

# %% [markdown]
# ## Using Python Tabulate Method
#
# Tabulate is a module that allows you to create tables out of your data. The ideal data types to be worked with here include
# - lists of lists
# - dictionaries
#
# It allows you to create the data and also format the table. (you will find out why you need to format it!)
# Check out the documentation here: https://pyneng.readthedocs.io/en/latest/book/12_useful_modules/tabulate.html#

# %%
# installing the tabulate module
# !pip install tabulate

# %%
from tabulate import tabulate

# %%
# created copied from a github repository
# https://gist.github.com/pamelafox/ad4f6abbaac0a48aa781


data = [['name','population','percent_one_year_change','population_change','density_per_sq_km','area_sq_km','net_migrants','fertility_rate','median_age','percent_of_world_pop'], 
['China',1439323776,0.39,5540090,153,9388211,-348399,1.70,38.00,18.47],
['India',1380004385,0.99,13586631,464,2973190,-532687,2.20,28.00,17.7],
['United States',331002651,0.59,1937734,36,9147420,954806,1.80,38.00,4.25],
['Indonesia',273523615,1.07,2898047,151,1811570,-98955,2.30,30.00,3.51],
['Pakistan',220892340,2.00,4327022,287,770880,-233379,3.60,23.00,2.83],
['Brazil',212559417,0.72,1509890,25,8358140,21200,1.70,33.00,2.73],
['Nigeria',206139589,2.58,5175990,226,910770,-60000,5.40,18.00,2.64],
['Bangladesh',164689383,1.01,1643222,1265,130170,-369501,2.10,28.00,2.11],
['Russia',145934462,0.04,62206,9,16376870,182456,1.80,40.00,1.87],
['Mexico',128932753,1.06,1357224,66,1943950,-60000,2.10,29.00,1.65],
['Japan',126476461,-0.30,-383840,347,364555,71560,1.40,48.00,1.62],
['Ethiopia',114963588,2.57,2884858,115,1000000,30000,4.30,19.00,1.47],
['Philippines',109581078,1.35,1464463,368,298170,-67152,2.60,26.00,1.41],
['Egypt',102334404,1.94,1946331,103,995450,-38033,3.30,25.00,1.31],
['Vietnam',97338579,0.91,876473,314,310070,-80000,2.10,32.00,1.25],
['DR Congo',89561403,3.19,2770836,40,2267050,23861,6.00,17.00,1.15],
['Turkey',84339067,1.09,909452,110,769630,283922,2.10,32.00,1.08],
['Iran',83992949,1.30,1079043,52,1628550,-55000,2.20,32.00,1.08]]

# %% [markdown]
# #### Creating the Table

# %%
# creating the table
table1 = tabulate(data)
print(table1)

# %% [markdown]
# #### Including Headers Within the Data
#
# The Headers allows you to specify the column names.

# %%
# we use the first row as a header
table2 = tabulate(data,headers='firstrow')
print(table2)

# %% [markdown]
# #### Styling the Table
#
# Styling involves making the table visually appealing. You could use parameters like **tablefmt,stralign**

# %%
table2 = tabulate(data,headers='firstrow', tablefmt='plain')
print(table2)

# %%
table2 = tabulate(data,headers='firstrow', tablefmt='grid', showindex='always')
print(table2)

# %%
table2 = tabulate(data,headers='firstrow', tablefmt='pipe', stralign='center')
print(table2)

# %% [markdown]
# ## WEB SCRAPING IN PYTHON
#
# Collecting and extracting data from a website. The data is collected into a format that will be useful for the user.
# It could be as simple as copy and pasting content from a website, using chatbots or third party applications for it.
#
# ## To Scrape the Web
# 1. Find the URL
# 2. Inspect the page
# 3. Find the data to extract
# 4. write the code
# 5. Extract the data
# 6. Store the data in the required format

# %% [markdown]
# Requests cannot convert the data into a useful form for analysis

# %%
# !pip install requests

# %%
# !pip install selenium

# %%
# !pip install beautifulsoup4

# %%
pip install html5lib

# %%
#importing libraries
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest companies in the United States by revenue - Wikipedia</title>
# ...

# %% [markdown]
# ### We inspect the page, specify the data we want

# %%
# specify the data you need
table = soup.find_all('table')[1]
print(table)
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
# picking out the titles
titles = table.find_all('th')
print(titles)
# Out:
# [<th>Rank
# </th>, <th>Name
# </th>, <th>Industry
# </th>, <th>Revenue <br/>(USD millions)
# </th>, <th>Revenue growth
# </th>, <th>Employees
# </th>, <th>Headquarters
# </th>]

# %%
# list comprehension
table_titles = [title.text for title in titles]
print(table_titles)
# Out:
# ['Rank\n', 'Name\n', 'Industry\n', 'Revenue (USD millions)\n', 'Revenue growth\n', 'Employees\n', 'Headquarters\n']

# %% [markdown]
# The output has extrenous characters in them. There is a method that works on the string data type called .strip() it removes white spaces that precede and succede string data types. the **\n** supposes that the texts had spaces close to them

# %%
table_titles = [title.text.strip() for title in titles]
print(table_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue (USD millions)', 'Revenue growth', 'Employees', 'Headquarters']

# %%
#creating a dataframe
worldie = pd.DataFrame(columns = table_titles)
worldie
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %% [markdown]
# We have dealt with the header. We now will be getting the body of the table. From the inspection, <tr> tags house the rows while the <td> tags, house the data

# %%
column_data = table.find_all('tr')
for row in column_data:
    row_data = row.find_all('td')
    
    # cleaning the data
    clean_row = [data.text.strip() for data in row_data]
    print(clean_row)
# Out:
# []
# ['1', 'Walmart', 'Retail', '611,289', '6.7%', '2,100,000', 'Bentonville, Arkansas']
# ['2', 'Amazon', 'Retail and Cloud Computing', '513,983', '9.4%', '1,540,000', 'Seattle, Washington']
# ['3', 'Exxon Mobil', 'Petroleum industry', '413,680', '44.8%', '62,000', 'Spring, Texas']
# ['4', 'Apple', 'Electronics industry', '394,328', '7.8%', '164,000', 'Cupertino, California']
# ['5', 'UnitedHealth Group', 'Healthcare', '324,162', '12.7%', '400,000', 'Minnetonka, Minnesota']
# ['6', 'CVS Health', 'Healthcare', '322,467', '10.4%', '259,500', 'Woonsocket, Rhode Island']
# ['7', 'Berkshire Hathaway', 'Conglomerate', '302,089', '9.4%', '383,000', 'Omaha, Nebraska']
# ['8', 'Alphabet', 'Technology', '282,836', '9.8%', '156,000', 'Mountain View, California']
# ['9', 'McKesson Corporation', 'Health', '276,711', '4.8%', '48,500', 'Irving, Texas']
# ['10', 'Chevron Corporation', 'Petroleum industry', '246,252', '51.6%', '43,846', 'San Ramon, California']
# ...

# %% [markdown]
# ### Arranging the Rows into  a Pandas DataFrame

# %%
column_data = table.find_all('tr')
for row in column_data[1:]:
    row_data = row.find_all('td')
    
    # cleaning the data
    clean_row = [data.text.strip() for data in row_data]
    
    length = len(worldie)
    worldie.loc[length] = clean_row

# %%
worldie
# Out:
#     Rank                      Name                    Industry  \
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and Cloud Computing
# 2      3               Exxon Mobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 195   96                  Best Buy                      Retail
# 196   97      Bristol-Myers Squibb     Pharmaceutical industry
# 197   98           United Airlines                     Airline
# 198   99  Thermo Fisher Scientific      Laboratory instruments
# 199  100                  Qualcomm                  Technology
#
#     Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                  611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
worldie.to_csv(r"C:\Users\Joana\Downloads\top_companies.csv", index=False)

# %% [markdown]
# ## Regular Expressions

# %% [markdown]
# Regular expressions are unique strings that are used to specify a search pattern. Regex uses a specific sequence of letters to identify the presence or absence of texts and splits the pattern into one or more sub-patterns. This concept is mainly useful in data cleaning
#
#
# Python has an in-built module for creating and manipulating regular expressions, called re. The general syntax for regular expression's search is typically,
#
#
#  - Match = re.search (pattern, str)
#
#  Syntax
#
# -  .search - is an re function
#
# - pattern - characterizes the search party
#
# - str - characterizes the string that is being searched

# %% [markdown]
# re.search(pattern, string) - Returns the first instance of the pattern in a given text. The .search () function checks within the text for the first occurrence and returns a match object or None otherwise. Example:

# %%
import re

# %%
# finds the first occurence of the pattern

poem = 'Peter Piper picked a peck of pickled peppers; A peck of pickled peppers Peter Piper picked'
re.search('picked', poem)

# %% [markdown]
# re.match(pattern, str) - The match function is used to check a pattern expression against a text. The .match() function checks for the presence of a pattern only at the beginning of the text. Example:

# %%
# finds the occurence of the pattern at the start of the text
poem = 'Peter Piper picked a peck of pickled peppers; A peck of pickled peppers Peter Piper picked;'
z=re.match('picked', poem)
print(z)

# %% [markdown]
# re.findall(pattern, str) - Returns all the occurrences of a pattern in a list. .findall() differs from .search() and .match() by printing  the  recurring outcomes. Example

# %%
# returns a list of all the times the pattern occured

poem = 'Peter Piper picked a peck of pickled peppers; A peck of pickled peppers Peter Piper picked;'
re.findall('picked', poem)

# %% [markdown]
# re.split() - Splits the input based on each occurrence of a pattern. Example:

# %%
poem = 'Peter Piper picked a peck of pickled peppers; A peck of pickled peppers Peter Piper picked;'

# the '\s' splits on white spaces
re.split(r'\s', poem)

# %% [markdown]
# re.sub(pattern, repl, str) - Replaces an old pattern with a new one. Example: It is about to get hot in here...

# %%
poem = 'Peter Piper picked a peck of pickled peppers; A         peck of pickled peppers Peter Piper picked;'
re.sub('picked', 'chewed', poem)

# %% [markdown]
# #### Special characters for Regular Expressions
#
# Regular expressions are regularised (:D) with the help of some special characters, metacharacters. The functions of the characters are simplified in the table below:

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# These characters help you to format the outputs of your search
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Practical Applications of Regex

# %%
# extracting e-mails

mail = """From: adwumapa27@gmail.com\
Sent: 16th October, 2021\
To: owusea15@yahoo.com\
Subject: Paper Towel Ventures\
Thank you for choosing us. For bulk purchases, email our Ghanaian correspondent through \
plemanbee1vent@gmail.com\
best,\
Joana :D"""

re.findall("[\w.-]+@[\w.-]+", mail)
